# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:9b352f27-8d30-43de-b87e-05c8324ed6f7.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized
#
#
# ![3-intro.png](attachment:c515b313-be96-44a4-ac54-25fd6ae6e2fb.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# ordered list
#
# 1-Python
#
# 2-R
#
# 3-SQL
#
# 4-Scala
#
# 5-Java
#
#
# ![4-dslanguages.png](attachment:6bf1ae8a-6bab-4da7-86c5-f1e841b06d4a.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# ordered list
#
# 1-Keras
#
# 2-SciKit-Learn
#
# 3-TensorFlow
#
# 4-Pytorch
#
# 5-Matplotlib
#
#
# ![5-dslibraries.png](attachment:3ae3baa0-53fa-4e7c-a881-c1d83ec1b8b0.png)

# %% [markdown]
# | Data Science Tools |
#
# |--- ||---||---|
#
# | RStudio || Apache Spark || TensorFlow |
#
# |--- ||---||---|
#
# ![6-dstools.png](attachment:c17d3bc2-37df-4c03-9800-53045375b600.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
#
# ![7-introarithmetic.png](attachment:afcacbc4-ec8f-4630-972c-0c22318a260b.png)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:2c7f7970-3c27-44f6-a23d-08c916ba27ea.png)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:91078eae-df2d-4c3c-b411-d43f6a0b8942.png)

# %% [markdown]
# __Objectives:__
#
# unordered list : Languages for Data science - Libraries fro Data science - Data science tools
#
# ![10-objectives.png](attachment:38b19f2e-4370-49e9-932d-fb25b878bebd.png)

# %% [markdown]
# ## Author
#    Bruno Oliveira
#
#
# ![11-authordetails.png](attachment:b18d7d8c-7809-4e55-9f53-6f626b810970.png)
